# %%
import pandas as pd
import sqlalchemy
import requests
import time
import datetime

# %%
# Replace with your Twitch API credentials
CLIENT_ID = "0bshbmlnl24klcvy4d9jw5qpyi8zir"
CLIENT_SECRET = "s7gvpxddel72bqllnet73cv1ygwi69"

# Function to get OAuth Token
def get_twitch_token():
    url = "https://id.twitch.tv/oauth2/token"
    params = {
        "client_id": CLIENT_ID,
        "client_secret": CLIENT_SECRET,
        "grant_type": "client_credentials"
    }
    response = requests.post(url, params=params)

    if response.status_code != 200:
        print("❌ Error getting token:", response.status_code, response.text)
        return None

    return response.json().get("access_token")

# Fetch token
TOKEN = get_twitch_token()
if not TOKEN:
    print("❌ Failed to authenticate with Twitch API.")
    exit()

# Define API Headers
HEADERS = {
    "Client-ID": CLIENT_ID,
    "Authorization": f"Bearer {TOKEN}"
}

print("✅ Twitch API Authentication Successful!")
# Out:
# ✅ Twitch API Authentication Successful!

# %%
# Function to get top games dynamically
def get_top_games(limit=30):
    url = "https://api.twitch.tv/helix/games/top"
    params = {"first": limit}
    response = requests.get(url, headers=HEADERS, params=params)
    
    if response.status_code != 200:
        print("❌ Error fetching top games:", response.status_code, response.text)
        return []

    games = response.json().get("data", [])
    return [game["name"] for game in games]

# Get top 30 games dynamically
top_games = get_top_games()
print(f"🎮 Top {len(top_games)} Games Fetched from Twitch API!")

# Manually selected diverse games
manual_games = [
    "Stardew Valley", "Hollow Knight", "Dark Souls 3", "Terraria", 
    "The Sims 4", "Cities: Skylines", "Final Fantasy XIV", "Tekken 8",
    "Street Fighter 6", "Age of Empires IV", "Elden Ring", "Rocket League",
    "Dead by Daylight", "Palworld", "Enshrouded", "Cyberpunk 2077",
    "Resident Evil 4", "The Legend of Zelda: Breath of the Wild",
    "Super Smash Bros. Ultimate", "Call of Duty: Warzone"
]

# Combine top games with manually selected ones
games_list = top_games + manual_games
print(f"🎮 Total Games to Analyze: {len(games_list)}")
# Out:
# 🎮 Top 30 Games Fetched from Twitch API!
# 🎮 Total Games to Analyze: 50

# %%
# Function to fetch Game ID from Twitch API
def get_game_id(game_name):
    url = "https://api.twitch.tv/helix/games"
    params = {"name": game_name}
    response = requests.get(url, headers=HEADERS, params=params)

    if response.status_code != 200:
        print(f"❌ Error fetching Game ID for {game_name}: {response.status_code}")
        return None

    data = response.json()
    if "data" in data and len(data["data"]) > 0:
        return data["data"][0]["id"]

    print(f"❌ Game '{game_name}' not found!")
    return None

# %%
# Function to fetch all small streamers playing a specific game (with pagination)
def get_small_streamers(game_name):
    print(f"🔍 Fetching Small Streamers for: {game_name}")

    game_id = get_game_id(game_name)
    if not game_id:
        return []

    url = "https://api.twitch.tv/helix/streams"
    params = {
        "game_id": game_id,
        "first": 100  # ✅ Fetch max 100 results per request
    }

    streamers = []
    cursor = None  # ✅ Used for pagination

    while True:
        if cursor:
            params["after"] = cursor  # Add cursor for next page

        response = requests.get(url, headers=HEADERS, params=params)

        if response.status_code != 200:
            print("❌ Error fetching streamers:", response.status_code, response.text)
            break  

        data = response.json()

        for stream in data.get("data", []):
            if 5 <= stream.get("viewer_count", 0) <= 100:  # ✅ Filter small streamers
                streamers.append({
                    "streamer_name": stream["user_name"],
                    "game": game_name,
                    "viewers": stream["viewer_count"],
                    "start_time": stream["started_at"],
                    "user_login": stream["user_login"], 
                    "stream_id": stream["id"],
                    "language": stream["language"],  # ✅ Added Language
                    "title": stream["title"],  # ✅ Added Stream Title
                    "tags": ", ".join(stream.get("tags", [])) if isinstance(stream.get("tags", []), list) else ""  # ✅ Fixed Tags
                })

        cursor = data.get("pagination", {}).get("cursor")
        if not cursor:  
            break  

    print(f"✅ {len(streamers)} Small Streamers Found for {game_name}")
    return streamers

# %%
# Function to calculate stream duration
def calculate_stream_duration(start_time):
    start_time = datetime.datetime.strptime(start_time, "%Y-%m-%dT%H:%M:%SZ")
    current_time = datetime.datetime.utcnow()
    duration = current_time - start_time
    return duration.total_seconds() // 60  # Convert to minutes

# %%
all_streamers = []

for game in games_list:
    small_streamers = get_small_streamers(game)

    # ✅ Compute stream duration before adding to dataset
    for streamer in small_streamers:
        streamer["duration"] = calculate_stream_duration(streamer["start_time"])

    all_streamers.extend(small_streamers)

print(f"\n✅ Total Streamers Collected: {len(all_streamers)}")

# ✅ Compute Game-Level Metrics (New Additions)
df_streamers = pd.DataFrame(all_streamers)

# Compute total viewers per game
game_viewers = df_streamers.groupby("game")["viewers"].sum().reset_index()
game_viewers.columns = ["game", "total_game_viewers"]

# Compute total active streams per game
game_streams = df_streamers.groupby("game")["stream_id"].count().reset_index()
game_streams.columns = ["game", "active_streams"]

# Merge with main dataframe
df_streamers = df_streamers.merge(game_viewers, on="game", how="left")
df_streamers = df_streamers.merge(game_streams, on="game", how="left")

# Compute average viewers per game
df_streamers["avg_viewers_per_game"] = df_streamers["total_game_viewers"] / df_streamers["active_streams"]
# Out:
# 🔍 Fetching Small Streamers for: Just Chatting
# ✅ 2366 Small Streamers Found for Just Chatting
# 🔍 Fetching Small Streamers for: League of Legends
# C:\Users\Bruno\AppData\Local\Temp\ipykernel_41648\1004084515.py:4: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   current_time = datetime.datetime.utcnow()
# ✅ 701 Small Streamers Found for League of Legends
# 🔍 Fetching Small Streamers for: Counter-Strike
# ✅ 655 Small Streamers Found for Counter-Strike
# 🔍 Fetching Small Streamers for: Grand Theft Auto V
# ✅ 1122 Small Streamers Found for Grand Theft Auto V
# 🔍 Fetching Small Streamers for: Assassin's Creed Shadows
# ✅ 949 Small Streamers Found for Assassin's Creed Shadows
# 🔍 Fetching Small Streamers for: Fortnite
# ✅ 1145 Small Streamers Found for Fortnite
# 🔍 Fetching Small Streamers for: VALORANT
# ✅ 1100 Small Streamers Found for VALORANT
# 🔍 Fetching Small Streamers for: World of Warcraft
# ✅ 792 Small Streamers Found for World of Warcraft
# 🔍 Fetching Small Streamers for: inZOI
# ✅ 169 Small Streamers Found for inZOI
# 🔍 Fetching Small Streamers for: Dota 2
# ✅ 368 Small Streamers Found for Dota 2
# 🔍 Fetching Small Streamers for: Marvel Rivals
# ✅ 466 Small Streamers Found for Marvel Rivals
# 🔍 Fetching Small Streamers for: Overwatch 2
# ✅ 391 Small Streamers Found for Overwatch 2
# 🔍 Fetching Small Streamers for: Minecraft
# ✅ 691 Small Streamers Found for Minecraft
# 🔍 Fetching Small Streamers for: R.E.P.O.
# ✅ 741 Small Streamers Found for R.E.P.O.
# 🔍 Fetching Small Streamers for: World of Tanks
# ✅ 106 Small Streamers Found for World of Tanks
# 🔍 Fetching Small Streamers for: PUBG: BATTLEGROUNDS
# ✅ 238 Small Streamers Found for PUBG: BATTLEGROUNDS
# 🔍 Fetching Small Streamers for: Call of Duty: Warzone
# ✅ 400 Small Streamers Found for Call of Duty: Warzone
# 🔍 Fetching Small Streamers for: Hearthstone
# ✅ 65 Small Streamers Found for Hearthstone
# 🔍 Fetching Small Streamers for: IRL
# ✅ 89 Small Streamers Found for IRL
# 🔍 Fetching Small Streamers for: Dead by Daylight
# ✅ 621 Small Streamers Found for Dead by Daylight
# 🔍 Fetching Small Streamers for: EA Sports FC 25
# ✅ 188 Small Streamers Found for EA Sports FC 25
# 🔍 Fetching Small Streamers for: Apex Legends
# ✅ 344 Small Streamers Found for Apex Legends
# 🔍 Fetching Small Streamers for: Rust
# ✅ 147 Small Streamers Found for Rust
# 🔍 Fetching Small Streamers for: Teamfight Tactics
# ✅ 87 Small Streamers Found for Teamfight Tactics
# 🔍 Fetching Small Streamers for: Wreckfest 2
# ✅ 43 Small Streamers Found for Wreckfest 2
# 🔍 Fetching Small Streamers for: Escape from Tarkov
# ✅ 182 Small Streamers Found for Escape from Tarkov
# 🔍 Fetching Small Streamers for: Talk Shows & Podcasts
# ✅ 71 Small Streamers Found for Talk Shows & Podcasts
# 🔍 Fetching Small Streamers for: Monster Hunter Wilds
# ✅ 446 Small Streamers Found for Monster Hunter Wilds
# 🔍 Fetching Small Streamers for: Slots
# ✅ 53 Small Streamers Found for Slots
# 🔍 Fetching Small Streamers for: DARK SOULS II: Scholar of the First Sin
# ✅ 23 Small Streamers Found for DARK SOULS II: Scholar of the First Sin
# 🔍 Fetching Small Streamers for: Stardew Valley
# ✅ 101 Small Streamers Found for Stardew Valley
# 🔍 Fetching Small Streamers for: Hollow Knight
# ✅ 35 Small Streamers Found for Hollow Knight
# 🔍 Fetching Small Streamers for: Dark Souls 3
# ✅ 46 Small Streamers Found for Dark Souls 3
# 🔍 Fetching Small Streamers for: Terraria
# ✅ 18 Small Streamers Found for Terraria
# 🔍 Fetching Small Streamers for: The Sims 4
# ✅ 78 Small Streamers Found for The Sims 4
# 🔍 Fetching Small Streamers for: Cities: Skylines
# ✅ 1 Small Streamers Found for Cities: Skylines
# 🔍 Fetching Small Streamers for: Final Fantasy XIV
# ✅ 77 Small Streamers Found for Final Fantasy XIV
# 🔍 Fetching Small Streamers for: Tekken 8
# ✅ 46 Small Streamers Found for Tekken 8
# 🔍 Fetching Small Streamers for: Street Fighter 6
# ✅ 42 Small Streamers Found for Street Fighter 6
# 🔍 Fetching Small Streamers for: Age of Empires IV
# ✅ 11 Small Streamers Found for Age of Empires IV
# 🔍 Fetching Small Streamers for: Elden Ring
# ✅ 173 Small Streamers Found for Elden Ring
# 🔍 Fetching Small Streamers for: Rocket League
# ✅ 167 Small Streamers Found for Rocket League
# 🔍 Fetching Small Streamers for: Dead by Daylight
# ✅ 682 Small Streamers Found for Dead by Daylight
# 🔍 Fetching Small Streamers for: Palworld
# ✅ 33 Small Streamers Found for Palworld
# 🔍 Fetching Small Streamers for: Enshrouded
# ✅ 39 Small Streamers Found for Enshrouded
# 🔍 Fetching Small Streamers for: Cyberpunk 2077
# ✅ 42 Small Streamers Found for Cyberpunk 2077
# 🔍 Fetching Small Streamers for: Resident Evil 4
# ✅ 32 Small Streamers Found for Resident Evil 4
# 🔍 Fetching Small Streamers for: The Legend of Zelda: Breath of the Wild
# ✅ 11 Small Streamers Found for The Legend of Zelda: Breath of the Wild
# 🔍 Fetching Small Streamers for: Super Smash Bros. Ultimate
# ✅ 39 Small Streamers Found for Super Smash Bros. Ultimate
# 🔍 Fetching Small Streamers for: Call of Duty: Warzone
# ✅ 377 Small Streamers Found for Call of Duty: Warzone
#
# ✅ Total Streamers Collected: 16809

# %%
# ✅ Display the first 10 rows of the DataFrame
from IPython.display import display
display(df_streamers.head(10))

# ✅ Save the data to a CSV file for easy review
df_streamers.to_csv("twitch_small_streamers.csv", index=False)

print("\n✅ Data saved as 'twitch_small_streamers.csv'. You can open it to check the full dataset.")
# Out:
#   streamer_name           game  viewers            start_time     user_login  \
# 0      taybisox  Just Chatting       72  2025-03-20T16:10:23Z       taybisox
# 1          小熙肉絲  Just Chatting       99  2025-03-20T17:47:15Z  sophroseeeeee
# 2       Felikah  Just Chatting       97  2025-03-20T18:47:30Z        felikah
# 3  GetOnMyLvLTV  Just Chatting       96  2025-03-19T12:06:37Z   getonmylvltv
# 4     LaserLent  Just Chatting      100  2025-03-20T17:31:13Z      laserlent
# 5       kitnip_  Just Chatting      100  2025-03-20T17:16:08Z        kitnip_
# 6      niconing  Just Chatting      100  2025-03-20T16:27:49Z       niconing
# 7     bioyundan  Just Chatting      100  2025-03-20T04:17:47Z      bioyundan
# 8        Wudjer  Just Chatting      100  2025-03-20T12:38:51Z         wudjer
# 9      TuikassZ  Just Chatting      100  2025-03-20T14:31:03Z       tuikassz
#
#       stream_id language                                              title  \
# 0  319354193149       ru  ДОБРЫЙ АУК НА ФИЛЬМ/ANIME (без правил, 1 прави...
# 1  315130774264       zh                                       3/21 救命 圍巾批發
# 2  318151777788       de  🔴 PUMMEL PARTY ACTION 🔴 ELDEN RING 🔴 GODRICK D...
# 3  317412970361       de  24.07.2020 - Numero Uno | 24/7 alte Streams & ...
# 4  318146482172       es  DALAS se VUELVE TOTALMETE LOCO, FRANK CUESTA E...
# 5  317471611385       en              first ever IRL strim | !kofi !socials
# 6  318143839868       ko               [replay/VOD] pretty nico🤍 💗 (eng/tw)
# 7  317448700921       tr         Videolarla championstv! 7/24 bant yayın...
# 8  317461084153       ru  🔴 Смотрим какой-то фильм . Начало в 20:00 → Ро...
# 9  314524179444       pt                                      LIVE BOA COLA
#
#                                                 tags  duration  \
# 0  Русский, девушка, общение, girl, Cosplay, аним...     195.0
# 1               中文, 奶茶千杯不醉, 香水收藏家, kpop, 年度熬夜亞軍, 儀式感      98.0
# 2                          Deutsch, gaming, GHG, 7tv      38.0
# 3                                            Deutsch    1879.0
# 4      Español, videojuegos, videojuegos, actualidad     114.0
# 5                     Girl, English, Swedish, Chatty     129.0
# 6                                                한국어     177.0
# 7                                     türkçe, Türkçe     907.0
# 8  Русский, DropsEnable, Pvp, Красивыймужчина, ге...     406.0
# 9                                          Português     294.0
#
#    total_game_viewers  active_streams  avg_viewers_per_game
# 0               55380            2366             23.406593
# 1               55380            2366             23.406593
# 2               55380            2366             23.406593
# 3               55380            2366             23.406593
# 4               55380            2366             23.406593
# 5               55380            2366             23.406593
# 6               55380            2366             23.406593
# 7               55380            2366             23.406593
# 8               55380            2366             23.406593
# 9               55380            2366             23.406593
# ✅ Data saved as 'twitch_small_streamers.csv'. You can open it to check the full dataset.
